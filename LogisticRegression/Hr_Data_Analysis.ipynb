# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('HR_Data_Exer.csv')
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  leftOrNot  \
# 0                       157                   3              0          1
# 1                       262                   6              0          1
# ...

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  leftOrNot  promotion_last_5years  \
# 0                   3              0          1                      0
# 1                   6              0          1                      0
# 2                   4              0          1                      0
# 3                   5              0          1                      0
# 4                   3              0          1                      0
#
#   Department  salary
# 0      sales     low
# 1      sales  medium
# ...

# %% [markdown]
# # Data Exploration

# %% [markdown]
# #### First we make saperate data frames of employees who left the companey and who retained in the companey.

# %%
left = df[df.leftOrNot==1]
left
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  leftOrNot  \
# 0                       157                   3              0          1
# 1                       262                   6              0          1
# ...

# %%
remain = df[df.leftOrNot == 0]
remain
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 2000                 0.58             0.74               4
# 2001                 0.82             0.67               2
# 2002                 0.45             0.69               5
# 2003                 0.78             0.82               5
# 2004                 0.49             0.60               3
# ...                   ...              ...             ...
# 14206                0.90             0.55               3
# 14207                0.74             0.95               5
# 14208                0.85             0.54               3
# 14209                0.33             0.65               3
# 14210                0.50             0.73               4
#
#        average_montly_hours  time_spend_company  Work_accident  leftOrNot  \
# 2000                    215                   3              0          0
# 2001                    202                   3              0          0
# ...

# %%
gp = df.groupby('leftOrNot')
for i,i_df in gp:
    print(i)
    print(i_df)
# Out:
# 0
#        satisfaction_level  last_evaluation  number_project  \
# 2000                 0.58             0.74               4
# 2001                 0.82             0.67               2
# 2002                 0.45             0.69               5
# 2003                 0.78             0.82               5
# 2004                 0.49             0.60               3
# ...                   ...              ...             ...
# 14206                0.90             0.55               3
# 14207                0.74             0.95               5
# 14208                0.85             0.54               3
# 14209                0.33             0.65               3
# 14210                0.50             0.73               4
#
#        average_montly_hours  time_spend_company  Work_accident  leftOrNot  \
# 2000                    215                   3              0          0
# 2001                    202                   3              0          0
# ...

# %%
gp.get_group(0).mean()
# Out:
# satisfaction_level         0.666810
# last_evaluation            0.715473
# number_project             3.786664
# average_montly_hours     199.060203
# time_spend_company         3.380032
# Work_accident              0.175009
# leftOrNot                  0.000000
# promotion_last_5years      0.026251
# dtype: float64

# %%
gp.get_group(0).satisfaction_level.mean()
# Out:
# 0.666809590479516

# %%
gp.mean()
# Out:
#            satisfaction_level  last_evaluation  number_project  \
# leftOrNot
# 0                    0.666810         0.715473        3.786664
# 1                    0.440098         0.718113        3.855503
#
#            average_montly_hours  time_spend_company  Work_accident  \
# leftOrNot
# 0                    199.060203            3.380032       0.175009
# 1                    207.419210            3.876505       0.047326
#
#            promotion_last_5years
# leftOrNot
# 0                       0.026251
# 1                       0.005321

# %% [markdown]
# ### From above table we can draw following conclusions
# 1. **Satisfaction Level**: Satisfaction level seems to be relatively low (0.44) in employees leaving the firm vs the retained ones (0.66)
# 2. **Average Monthly Hours**: Average monthly hours are higher in employees leaving the firm (199 vs 207)
# 3. **Promotion Last 5 Years**: Employees who are given promotion are likely to be retained at firm

# %% [markdown]
# ## Impact of salary on employee decision

# %%
pd.crosstab(df.salary,df.leftOrNot,normalize='index')
# Out:
# leftOrNot         0         1
# salary
# high       0.933711  0.066289
# low        0.703116  0.296884
# medium     0.795687  0.204313

# %%
pd.crosstab(df.salary,df.leftOrNot).plot(kind='bar')

# %% [markdown]
# ## Impact of Department on employee Decision

# %%
pd.crosstab(df.Department,df.leftOrNot,normalize='index')
# Out:
# leftOrNot           0         1
# Department
# IT           0.777506  0.222494
# RandD        0.846252  0.153748
# accounting   0.734029  0.265971
# hr           0.709066  0.290934
# management   0.855556  0.144444
# marketing    0.763403  0.236597
# product_mng  0.780488  0.219512
# sales        0.755072  0.244928
# support      0.751009  0.248991
# technical    0.743750  0.256250

# %%
pd.crosstab(df.Department,df.leftOrNot).plot(kind='bar')

# %% [markdown]
# ## Impact of Work_accident on employee Job

# %%
pd.crosstab(df.Work_accident,df.leftOrNot,normalize='index')
# Out:
# leftOrNot             0         1
# Work_accident
# 0              0.734840  0.265160
# 1              0.922084  0.077916

# %%
pd.crosstab(df.Work_accident,df.leftOrNot).plot(kind='bar')

# %% [markdown]
# ## Impact of Promotion on employee Job

# %%
pd.crosstab(df.promotion_last_5years,df.leftOrNot,normalize='index')
# Out:
# leftOrNot                     0         1
# promotion_last_5years
# 0                      0.758038  0.241962
# 1                      0.940439  0.059561

# %%
pd.crosstab(df.promotion_last_5years,df.leftOrNot).plot(kind='bar')

# %% [markdown]
# ## Impact of No.of Project on employee Job

# %%
pd.crosstab(df.number_project,df.leftOrNot,normalize='index')
# Out:
# leftOrNot              0         1
# number_project
# 2               0.343802  0.656198
# 3               0.982244  0.017756
# 4               0.906300  0.093700
# 5               0.778341  0.221659
# 6               0.442078  0.557922
# 7               0.000000  1.000000

# %%
pd.crosstab(df.number_project,df.leftOrNot,normalize='index').plot(kind='bar')

# %% [markdown]
# From the data analysis so far we can conclude that we will use following variables as independant variables in our model
# 1. **Satisfaction Level**
# 2. **Average Monthly Hours**
# 3. **Promotion Last 5 Years**
# 4. **Salary**

# %%
subdf = df[['satisfaction_level','average_montly_hours','promotion_last_5years','salary']]
subdf
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  salary
# 0                    0.38                   157                      0     low
# 1                    0.80                   262                      0  medium
# 2                    0.11                   272                      0  medium
# 3                    0.72                   223                      0     low
# 4                    0.37                   159                      0     low
# ...                   ...                   ...                    ...     ...
# 14994                0.40                   151                      0     low
# 14995                0.37                   160                      0     low
# 14996                0.37                   143                      0     low
# 14997                0.11                   280                      0     low
# 14998                0.37                   158                      0     low
#
# ...

# %%
salary_dummies = pd.get_dummies(subdf.salary, prefix="salary")
salary_dummies
# Out:
#        salary_high  salary_low  salary_medium
# 0                0           1              0
# 1                0           0              1
# 2                0           0              1
# 3                0           1              0
# 4                0           1              0
# ...            ...         ...            ...
# 14994            0           1              0
# 14995            0           1              0
# 14996            0           1              0
# 14997            0           1              0
# 14998            0           1              0
#
# [14999 rows x 3 columns]

# %%
merge_df = pd.concat([subdf,salary_dummies],axis='columns')
merge_df
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  \
# 0                    0.38                   157                      0
# 1                    0.80                   262                      0
# 2                    0.11                   272                      0
# 3                    0.72                   223                      0
# 4                    0.37                   159                      0
# ...                   ...                   ...                    ...
# 14994                0.40                   151                      0
# 14995                0.37                   160                      0
# 14996                0.37                   143                      0
# 14997                0.11                   280                      0
# 14998                0.37                   158                      0
#
#        salary  salary_high  salary_low  salary_medium
# 0         low            0           1              0
# ...

# %%
final_df = merge_df.drop('salary',axis='columns')
final_df.head()
# Out:
#    satisfaction_level  average_montly_hours  promotion_last_5years  \
# 0                0.38                   157                      0
# 1                0.80                   262                      0
# 2                0.11                   272                      0
# 3                0.72                   223                      0
# 4                0.37                   159                      0
#
#    salary_high  salary_low  salary_medium
# 0            0           1              0
# 1            0           0              1
# 2            0           0              1
# 3            0           1              0
# 4            0           1              0

# %%
x = final_df
y = df.leftOrNot

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %% [markdown]
# ## Train Model

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %% [markdown]
# ## Accuracy Of The Model

# %%
model.score(x_test,y_test)
# Out:
# 0.7664444444444445

# %%
model.predict([[0.38,157,0,0,1,0]])
# Out:
# array([0], dtype=int64)

# %%
pd.crosstab(df.satisfaction_level,df.leftOrNot,normalize='index')
# Out:
# leftOrNot                  0         1
# satisfaction_level
# 0.09                0.000000  1.000000
# 0.10                0.000000  1.000000
# 0.11                0.000000  1.000000
# 0.12                0.866667  0.133333
# 0.13                0.944444  0.055556
# ...                      ...       ...
# 0.96                1.000000  0.000000
# 0.97                1.000000  0.000000
# 0.98                1.000000  0.000000
# 0.99                1.000000  0.000000
# 1.00                1.000000  0.000000
#
# [92 rows x 2 columns]

# %%
pd.crosstab(df.average_montly_hours,df.leftOrNot,normalize='index')
# Out:
# leftOrNot               0    1
# average_montly_hours
# 96                    1.0  0.0
# 97                    1.0  0.0
# 98                    1.0  0.0
# 99                    1.0  0.0
# 100                   1.0  0.0
# ...                   ...  ...
# 306                   0.0  1.0
# 307                   0.0  1.0
# 308                   0.0  1.0
# 309                   0.0  1.0
# 310                   0.0  1.0
#
# [215 rows x 2 columns]

# %%
pd.crosstab(df.last_evaluation,df.leftOrNot,normalize='index')
# Out:
# leftOrNot               0         1
# last_evaluation
# 0.36             1.000000  0.000000
# 0.37             1.000000  0.000000
# 0.38             1.000000  0.000000
# 0.39             1.000000  0.000000
# 0.40             1.000000  0.000000
# ...                   ...       ...
# 0.96             0.730924  0.269076
# 0.97             0.695652  0.304348
# 0.98             0.756654  0.243346
# 0.99             0.744186  0.255814
# 1.00             0.409894  0.590106
#
# [65 rows x 2 columns]
